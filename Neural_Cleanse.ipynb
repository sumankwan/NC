# %%
# !pip install git+https://github.com/RobustBench/robustbench.git
# !pip install torch torchvision -U

# %%
# !python drive/MyDrive/Neural-Cleanse-Pytorch/gtsrb_visualize_example.py
# Out:
# True
# 12.1
# loading dataset
# Files already downloaded and verified
# Files already downloaded and verified
# loading model
# ==> Building model..
# ==> Loading model from existing weights..
# processing label 6
# resetting state
# self.input_shape (3, 32, 32)
# mask.shape - init (32, 32)
# mask.shape - clip (32, 32)
# mask.shape - expand dims (1, 32, 32)
# mask_tanh -3.7462409542995845 3.4530466883337865
# pattern_tanh -4.798973586874538 3.9704292714645932
# mask.shape (1, 32, 32)
# mask_tensor_unexpand.shape torch.Size([3, 32, 32])
# self.mask_tensor.shape torch.Size([1, 3, 32, 32])
# mask_upsample_tensor_uncrop.shape torch.Size([1, 3, 32, 32])
# self.mask_upsample_tensor.shape torch.Size([1, 3, 32, 32])
# self.pattern_tanh_tensor.shape torch.Size([1, 3, 32, 32])
# step:   0, cost: 0.00E+00, attack: 0.195, loss: 4.651886, ce: 4.651886, reg: 505.469124, reg_best: inf
# step:   1, cost: 0.00E+00, attack: 0.456, loss: 3.471992, ce: 3.471992, reg: 506.339861, reg_best: inf
# ...

# %%
# !python drive/MyDrive/Neural-Cleanse-Pytorch/mad_outlier_detection.py
